# %%
'''
This code is creating a table called gdp in the database worldbank.db. The table has 5 columns: countryname, countrycode, year, gdp, and PRIMARY KEY (countrycode, year). The PRIMARY KEY is a combination of countrycode and year.
'''

import sqlite3

conn = sqlite3.connect('worldbank.db')

# get a cursor
cur = conn.cursor()

# drop the test table in case it already exists
cur.execute("DROP TABLE IF EXISTS gdp")

# create the test table including project_id as a primary key
cur.execute("CREATE TABLE gdp (countryname TEXT, countrycode TEXT, year INTEGER, gdp REAL, PRIMARY KEY (countrycode, year));")

conn.commit()
conn.close()

# %%
'''
A generator function that returns a generator object.
It reads the file line by line and yields the lines.
'''

def extract_lines(file):
    while True:
        line = file.readline()
        if not line:
            break
        yield line

# %%
import pandas as pd
import numpy as np
import sqlite3


def transform_indicator_data(data, colnames):
    
    # get rid of quote marks
    for i, datum in enumerate(data):
        data[i] = datum.replace('"','')
    
    country = data[0]
    
    # filter out values that are not countries
    non_countries = ['World',
     'High income',
     'OECD members',
     'Post-demographic dividend',
     'IDA & IBRD total',
     'Low & middle income',
     'Middle income',
     'IBRD only',
     'East Asia & Pacific',
     'Europe & Central Asia',
     'North America',
     'Upper middle income',
     'Late-demographic dividend',
     'European Union',
     'East Asia & Pacific (excluding high income)',
     'East Asia & Pacific (IDA & IBRD countries)',
     'Euro area',
     'Early-demographic dividend',
     'Lower middle income',
     'Latin America & Caribbean',
     'Latin America & the Caribbean (IDA & IBRD countries)',
     'Latin America & Caribbean (excluding high income)',
     'Europe & Central Asia (IDA & IBRD countries)',
     'Middle East & North Africa',
     'Europe & Central Asia (excluding high income)',
     'South Asia (IDA & IBRD)',
     'South Asia',
     'Arab World',
     'IDA total',
     'Sub-Saharan Africa',
     'Sub-Saharan Africa (IDA & IBRD countries)',
     'Sub-Saharan Africa (excluding high income)',
     'Middle East & North Africa (excluding high income)',
     'Middle East & North Africa (IDA & IBRD countries)',
     'Central Europe and the Baltics',
     'Pre-demographic dividend',
     'IDA only',
     'Least developed countries: UN classification',
     'IDA blend',
     'Fragile and conflict affected situations',
     'Heavily indebted poor countries (HIPC)',
     'Low income',
     'Small states',
     'Other small states',
     'Not classified',
     'Caribbean small states',
     'Pacific island small states']
    
    
    if country not in non_countries:
        data_array = np.array(data, ndmin=2)
        data_array.reshape(1, 63)
        df = pd.DataFrame(data_array, columns=colnames).replace('', np.nan)
        df.drop(['Indicator Name', 'Indicator Code'], inplace=True, axis=1)

        # Reshape the data sets so that they are in long format
        df_melt = df.melt(id_vars=['Country Name', 'Country Code'], 
                            var_name='year', 
                            value_name='gdp')
        
        results = []
        for index, row in df_melt.iterrows():
            country, countrycode, year, gdp = row
            if str(gdp) != 'nan':
                results.append([country, countrycode, year, gdp])
        return results

# %%
def load_indicator_data(results):
    conn = sqlite3.connect('worldbank.db')
    cur = conn.cursor()
    if results:
        for result in results:
            countryname, countrycode, year, gdp = result

            sql_string = 'INSERT INTO gdp (countryname, countrycode, year, gdp) VALUES ("{}", "{}", {}, {});'.format(countryname, countrycode, year, gdp)

            # connect to database and execute query
            try:
                cur.execute(sql_string)
            except Exception as e:
                print('error occurred:', e, result)
            
    conn.commit()
    conn.close()
    
    return None

# %%
# read the indicator data
# this block of code runs the ETL pipeline

with open('data\gdp_data.csv') as f:
    for line in extract_lines(f):
        data = line.split(',')
        if len(data) == 63:
            if data[0] == '"Country Name"':
                colnames = []
                # get rid of quote marks
                for i, datum in enumerate(data):
                    colnames.append(datum.replace('"',''))
            else:
                # transform and load the line of indicator data
                results = transform_indicator_data(data, colnames)
                load_indicator_data(results)
# Out:
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Aruba', 'ABW', '1994', '1330167597.76536']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Aruba', 'ABW', '1995', '1320670391.06145']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Aruba', 'ABW', '1996', '1379888268.15642']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Aruba', 'ABW', '1997', '1531843575.41899']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Aruba', 'ABW', '1998', '1665363128.49162']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Aruba', 'ABW', '1999', '1722798882.68156']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Aruba', 'ABW', '2000', '1873452513.96648']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Aruba', 'ABW', '2001', '1920262569.8324']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Aruba', 'ABW', '2002', '1941094972.06704']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Aruba', 'ABW', '2003', '2021301675.97765']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Aruba', 'ABW', '2004', '2228279329.60894']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Aruba', 'ABW', '2005', '2331005586.59218']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Aruba', 'ABW', '2006', '2421474860.3352']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Aruba', 'ABW', '2007', '2623726256.98324']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Aruba', 'ABW', '2008', '2791960893.85475']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Aruba', 'ABW', '2009', '2498932960.89385']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Aruba', 'ABW', '2010', '2467703910.61453']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Aruba', 'ABW', '2011', '2584463687.15084']
# error occurred: near ",": syntax error ['Aruba', 'ABW', '\n', '\n']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Afghanistan', 'AFG', '1960', '537777811.111111']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Afghanistan', 'AFG', '1961', '548888895.555556']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Afghanistan', 'AFG', '1962', '546666677.777778']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Afghanistan', 'AFG', '1963', '751111191.111111']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Afghanistan', 'AFG', '1964', '800000044.444444']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Afghanistan', 'AFG', '1965', '1006666637.77778']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Afghanistan', 'AFG', '1966', '1399999966.66667']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Afghanistan', 'AFG', '1967', '1673333417.77778']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Afghanistan', 'AFG', '1968', '1373333366.66667']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Afghanistan', 'AFG', '1969', '1408888922.22222']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Afghanistan', 'AFG', '1970', '1748886595.55556']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Afghanistan', 'AFG', '1971', '1831108971.11111']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Afghanistan', 'AFG', '1972', '1595555475.55556']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Afghanistan', 'AFG', '1973', '1733333264.44444']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Afghanistan', 'AFG', '1974', '2155555497.77778']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Afghanistan', 'AFG', '1975', '2366666615.55556']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Afghanistan', 'AFG', '1976', '2555555566.66667']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Afghanistan', 'AFG', '1977', '2953333417.77778']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Afghanistan', 'AFG', '1978', '3300000108.88889']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Afghanistan', 'AFG', '1979', '3697940409.61098']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Afghanistan', 'AFG', '1980', '3641723321.99546']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Afghanistan', 'AFG', '1981', '3478787909.09091']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Afghanistan', 'AFG', '2001', '2461665937.89386']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Afghanistan', 'AFG', '2002', '4128820723.04713']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Afghanistan', 'AFG', '2003', '4583644246.48061']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Afghanistan', 'AFG', '2004', '5285465685.86423']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Afghanistan', 'AFG', '2005', '6275073571.54659']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Afghanistan', 'AFG', '2006', '7057598406.61553']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Afghanistan', 'AFG', '2007', '9843842455.48323']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Afghanistan', 'AFG', '2008', '10190529882.4878']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Afghanistan', 'AFG', '2009', '12486943505.7381']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Afghanistan', 'AFG', '2010', '15936800636.2487']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Afghanistan', 'AFG', '2011', '17930239399.8149']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Afghanistan', 'AFG', '2012', '20536542736.7297']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Afghanistan', 'AFG', '2013', '20264253973.7858']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Afghanistan', 'AFG', '2014', '20616104298.4975']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Afghanistan', 'AFG', '2015', '19215562179.0117']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Afghanistan', 'AFG', '2016', '19469022207.6852']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Afghanistan', 'AFG', '2017', '20815300220.0428']
# error occurred: near ",": syntax error ['Afghanistan', 'AFG', '\n', '\n']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Angola', 'AGO', '1980', '5934073603.54849']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Angola', 'AGO', '1981', '5553824463.82274']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Angola', 'AGO', '1982', '5553824463.82274']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Angola', 'AGO', '1983', '5787823808.69565']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Angola', 'AGO', '1984', '6135166254.2408']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Angola', 'AGO', '1985', '7558613007.90635']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Angola', 'AGO', '1986', '7076793822.60201']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Angola', 'AGO', '1987', '8089279284.72241']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Angola', 'AGO', '1988', '8775116269.16722']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Angola', 'AGO', '1989', '10207922517.1839']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Angola', 'AGO', '1990', '11236275842.7358']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Angola', 'AGO', '1994', '3390500000']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Angola', 'AGO', '1995', '5561222222.22222']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Angola', 'AGO', '1996', '6537503912.36307']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Angola', 'AGO', '1997', '7676533742.33129']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Angola', 'AGO', '1998', '6506619144.60285']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Angola', 'AGO', '1999', '6152936539.21955']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Angola', 'AGO', '2000', '9129634978.33773']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Angola', 'AGO', '2001', '8936063723.20121']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Angola', 'AGO', '2002', '12497347956.1316']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Angola', 'AGO', '2003', '14188949398.3752']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Angola', 'AGO', '2004', '19640853733.598']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Angola', 'AGO', '2005', '28233712737.97']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Angola', 'AGO', '2006', '41789479931.7142']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Angola', 'AGO', '2007', '60448924661.7935']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Angola', 'AGO', '2008', '84178035578.8223']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Angola', 'AGO', '2009', '75492385928.3332']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Angola', 'AGO', '2010', '82526143645.0623']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Angola', 'AGO', '2011', '104115807985.965']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Angola', 'AGO', '2012', '113923162050.111']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Angola', 'AGO', '2013', '124912503781.148']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Angola', 'AGO', '2014', '126730196125.425']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Angola', 'AGO', '2015', '102621215573.456']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Angola', 'AGO', '2016', '95337203468.1156']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Angola', 'AGO', '2017', '124209385825.22']
# error occurred: near ",": syntax error ['Angola', 'AGO', '\n', '\n']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Albania', 'ALB', '1984', '1924242453.00929']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Albania', 'ALB', '1985', '1965384586.24229']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Albania', 'ALB', '

# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zambia', 'ZMB', '1989', '3998637681.15942']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zambia', 'ZMB', '1990', '3285217391.30435']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zambia', 'ZMB', '1991', '3378882352.94118']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zambia', 'ZMB', '1992', '3181921787.7095']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zambia', 'ZMB', '1993', '3273237853.35689']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zambia', 'ZMB', '1994', '3656647744.24858']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zambia', 'ZMB', '1995', '3807067121.8609']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zambia', 'ZMB', '1996', '3597220962.00017']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zambia', 'ZMB', '1997', '4303281932.29365']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zambia', 'ZMB', '1998', '3537683046.02331']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zambia', 'ZMB', '1999', '3404311976.54941']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zambia', 'ZMB', '2000', '3600683039.73254']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zambia', 'ZMB', '2001', '4094480988.11931']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zambia', 'ZMB', '2002', '4193845678.17033']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zambia', 'ZMB', '2003', '4901839731.26571']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zambia', 'ZMB', '2004', '6221077674.77871']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zambia', 'ZMB', '2005', '8331870169.14977']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zambia', 'ZMB', '2006', '12756858899.2812']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zambia', 'ZMB', '2007', '14056957976.2648']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zambia', 'ZMB', '2008', '17910858637.9048']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zambia', 'ZMB', '2009', '15328342303.9575']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zambia', 'ZMB', '2010', '20265556273.582']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zambia', 'ZMB', '2011', '23460098339.7453']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zambia', 'ZMB', '2012', '25503370699.2015']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zambia', 'ZMB', '2013', '28045460442.1876']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zambia', 'ZMB', '2014', '27150630607.2032']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zambia', 'ZMB', '2015', '21154394545.895']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zambia', 'ZMB', '2016', '20954754378.1394']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zambia', 'ZMB', '2017', '25808666421.5558']
# error occurred: near ",": syntax error ['Zambia', 'ZMB', '\n', '\n']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zimbabwe', 'ZWE', '1960', '1052990400']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zimbabwe', 'ZWE', '1961', '1096646600']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zimbabwe', 'ZWE', '1962', '1117601600']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zimbabwe', 'ZWE', '1963', '1159511700']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zimbabwe', 'ZWE', '1964', '1217138000']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zimbabwe', 'ZWE', '1965', '1311435800']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zimbabwe', 'ZWE', '1966', '1281749500']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zimbabwe', 'ZWE', '1967', '1397002000']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zimbabwe', 'ZWE', '1968', '1479599900']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zimbabwe', 'ZWE', '1969', '1747998800']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zimbabwe', 'ZWE', '1970', '1884206300']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zimbabwe', 'ZWE', '1971', '2178716300']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zimbabwe', 'ZWE', '1972', '2677729400']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zimbabwe', 'ZWE', '1973', '3309353600']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zimbabwe', 'ZWE', '1974', '3982161400']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zimbabwe', 'ZWE', '1975', '4371300700']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zimbabwe', 'ZWE', '1976', '4318372000']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zimbabwe', 'ZWE', '1977', '4364382100']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zimbabwe', 'ZWE', '1978', '4351600500']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zimbabwe', 'ZWE', '1979', '5177459400']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zimbabwe', 'ZWE', '1980', '6678868200']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zimbabwe', 'ZWE', '1981', '8011373800']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zimbabwe', 'ZWE', '1982', '8539700700']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zimbabwe', 'ZWE', '1983', '7764067000']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zimbabwe', 'ZWE', '1984', '6352125900']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zimbabwe', 'ZWE', '1985', '5637259300']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zimbabwe', 'ZWE', '1986', '6217523700']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zimbabwe', 'ZWE', '1987', '6741215100']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zimbabwe', 'ZWE', '1988', '7814784100']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zimbabwe', 'ZWE', '1989', '8286322700']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zimbabwe', 'ZWE', '1990', '8783816700']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zimbabwe', 'ZWE', '1991', '8641481700']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zimbabwe', 'ZWE', '1992', '6751472200']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zimbabwe', 'ZWE', '1993', '6563813300']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zimbabwe', 'ZWE', '1994', '6890675000']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zimbabwe', 'ZWE', '1995', '7111270700']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zimbabwe', 'ZWE', '1996', '8553146600']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zimbabwe', 'ZWE', '1997', '8529571600']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zimbabwe', 'ZWE', '1998', '6401968200']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zimbabwe', 'ZWE', '1999', '6858013100']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zimbabwe', 'ZWE', '2000', '6689957600']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zimbabwe', 'ZWE', '2001', '6777384700']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zimbabwe', 'ZWE', '2002', '6342116400']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zimbabwe', 'ZWE', '2003', '5727591800']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zimbabwe', 'ZWE', '2004', '5805598400']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zimbabwe', 'ZWE', '2005', '5755215200']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zimbabwe', 'ZWE', '2006', '5443896500']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zimbabwe', 'ZWE', '2007', '5291950100']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zimbabwe', 'ZWE', '2008', '4415702800']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zimbabwe', 'ZWE', '2009', '8621573600']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zimbabwe', 'ZWE', '2010', '10141859700']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zimbabwe', 'ZWE', '2011', '12098450700']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zimbabwe', 'ZWE', '2012', '14242490300']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zimbabwe', 'ZWE', '2013', '15451768700']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zimbabwe', 'ZWE', '2014', '15891049200']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zimbabwe', 'ZWE', '2015', '16304667800']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zimbabwe', 'ZWE', '2016', '16619960400']
# error occurred: UNIQUE constraint failed: gdp.countrycode, gdp.year ['Zimbabwe', 'ZWE', '2017', '17845821400']
# error occurred: near ",": syntax error ['Zimbabwe', 'ZWE', '\n', '\n']

# %%
# Execute this code cell to output the values in the gdp table
# You do not need to change anything in this cell

# connect to the database
# the database file will be worldbank.db
# note that sqlite3 will create this database file if it does not exist already
conn = sqlite3.connect('worldbank.db')

# get a cursor
cur = conn.cursor()

# create the test table including project_id as a primary key
df = pd.read_sql("SELECT * FROM gdp", con=conn)

conn.commit()
conn.close()

df
# Out:
#      countryname countrycode  year           gdp
# 0          Aruba         ABW  1994  1.330168e+09
# 1          Aruba         ABW  1995  1.320670e+09
# 2          Aruba         ABW  1996  1.379888e+09
# 3          Aruba         ABW  1997  1.531844e+09
# 4          Aruba         ABW  1998  1.665363e+09
# ...          ...         ...   ...           ...
# 8709    Zimbabwe         ZWE  2013  1.545177e+10
# 8710    Zimbabwe         ZWE  2014  1.589105e+10
# 8711    Zimbabwe         ZWE  2015  1.630467e+10
# 8712    Zimbabwe         ZWE  2016  1.661996e+10
# 8713    Zimbabwe         ZWE  2017  1.784582e+10
#
# [8714 rows x 4 columns]
